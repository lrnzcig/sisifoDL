# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from keras.losses import mean_absolute_percentage_error
# Out:
# Using TensorFlow backend.

# %%
# watch for any changes in the utils module, and reload it automatically
# %load_ext autoreload
# %autoreload 2

# %%
from utils.generate_models import generate_models, generate_DeepConvLSTM_model
from utils.validate_models import find_best_architecture, evaluate_model, evaluate_plot
from utils.data_generator import DataGenerator
from utils.get_dataset_pulsi import get_dataset_pulsi

# %%
columns = np.array(['bpm', 'spo2'])
dataset_reduced_std, dataset_reduced = get_dataset_pulsi(columns,
                                                         filename='./utils/test_data/42nights.csv')

# %%
plt.plot(dataset_reduced[dataset_reduced["name"] == 'h_17-04-27']["spo2"])

# %%
plt.plot(dataset_reduced_std[dataset_reduced_std["name"] == 'h_17-04-27']["spo2"])

# %%
window_size = 12            # ventana de valores para la prediccion
dim_length = window_size
number_of_predictions = 4   # numero de predicciones en la salida
output_dim = number_of_predictions
target_variable = "spo2"
dim_channels = 2            # 2 variables

# %%
#cv_fold_size = len(val_gen)*batch_size
batch_size = 32
metric = mean_absolute_percentage_error

# %%
train_names_reduced = np.array(['p_17-01-19', 'p_17-01-20'])
val_names_reduced = np.array(['p_17-01-23'])
test_names_reduced = np.array(['p_17-01-24'])
train_gen_reduced = DataGenerator(dataset_reduced_std, train_names_reduced,
                                  "spo2", batch_size=batch_size,
                                  number_of_predictions=number_of_predictions,
                                  window_size=window_size,
                                  step_prediction_dates=1, shuffle=False,
                                  rebalance_data=True, rebalance_threshold=0.5,
                                  debug=False)
val_gen_reduced = DataGenerator(dataset_reduced_std, val_names_reduced,
                                "spo2", batch_size=batch_size,
                                number_of_predictions=number_of_predictions,
                                window_size=window_size,
                                step_prediction_dates=1, shuffle=False,
                                rebalance_data=True, rebalance_threshold=0.5,
                                debug=False)
test_gen_reduced = DataGenerator(dataset_reduced_std, test_names_reduced,
                                 "spo2", batch_size=batch_size,
                                 number_of_predictions=number_of_predictions,
                                 window_size=window_size,
                                 step_prediction_dates=1, shuffle=False,
                                 rebalance_data=False, debug=False)

# %%
print(len(train_gen_reduced)*batch_size)
print(len(train_gen_reduced.get_minority_datetimes()))
print(len(val_gen_reduced)*batch_size)
print(len(val_gen_reduced.get_minority_datetimes()))
# Out:
# 2496
# 20
# 1152
# 36

# %%
# simple
hyperparameters_simple = {}
regularization_rate_simple = 10 ** -4 # max bound
hyperparameters_simple['regularization_rate'] = regularization_rate_simple
learning_rate_simple = 10 ** -4 # max bound
hyperparameters_simple['learning_rate'] = learning_rate_simple
filters_simple = []
hyperparameters_simple['filters'] = filters_simple
lstm_dims_simple = [100]
hyperparameters_simple['lstm_dims'] = lstm_dims_simple

dropout_rnn_simple = 0.75
dropout_cnn_simple = 0.75

nrepochs_simple = 150

# %%
model = generate_DeepConvLSTM_model(dim_length, dim_channels, output_dim,
                                    filters_simple, lstm_dims_simple, learning_rate_simple,
                                    regularization_rate_simple, dropout=None,
                                    dropout_rnn=dropout_rnn_simple, dropout_cnn=dropout_cnn_simple,
                                    metrics=[mean_absolute_percentage_error])

models_simple = [(model, hyperparameters_simple)]

# %%
# in this case, find_best_architecture is only used for training the model
np.random.seed(3)
verbose=True
early_stopping=False

best_model_losses, best_params_losses, best_model_metrics, best_params_metrics, debug = \
    find_best_architecture(train_gen_reduced, val_gen_reduced, test_gen_reduced,
                           verbose=False, number_of_models=None, nr_epochs=nrepochs_simple,
                           early_stopping=True, batch_size=batch_size,
                           models=models_simple, metric=mean_absolute_percentage_error, use_testset=True,
                           debug=False, test_retrain=False, output_all=True)

# %%
train_predict, val_predict, test_predict = \
    evaluate_model(train_gen_reduced, val_gen_reduced, test_gen_reduced,
                   best_model_losses)
# Out:
# training error = [0.035784136527814925, 18021747.833333332]
# validation error = [0.02973803375951118, 25.182256168789333]
# testing error = [0.006432376613219579, 6.624536661783854]

# %%
# from GC_find_best_arch_250_rnn_1_pulsi_rebalance / losses
hyperparameters_losses = {}
regularization_rate_losses = 0.0002
hyperparameters_losses['regularization_rate'] = regularization_rate_losses
learning_rate_losses = 0.003
hyperparameters_losses['learning_rate'] = learning_rate_losses
filters_losses = []
hyperparameters_losses['filters'] = filters_losses
lstm_dims_losses = [17]
hyperparameters_losses['lstm_dims'] = lstm_dims_losses

dropout_rnn_losses = 0.84
dropout_cnn_losses = None

nrepochs_losses = 52

# %%
# from GC_find_best_arch_250_rnn_1_pulsi_rebalance / metrics
hyperparameters_losses = {}
regularization_rate_losses = 0.0004
hyperparameters_losses['regularization_rate'] = regularization_rate_losses
learning_rate_losses = 0.0008
hyperparameters_losses['learning_rate'] = learning_rate_losses
filters_losses = []
hyperparameters_losses['filters'] = filters_losses
lstm_dims_losses = [12]
hyperparameters_losses['lstm_dims'] = lstm_dims_losses

dropout_rnn_losses = 0.30
dropout_cnn_losses = None

nrepochs_losses = 66

# %%
# from GC_find_best_arch_250_rnn_1_cnn_1_pulsi_rebalance / lossses
hyperparameters_losses = {}
regularization_rate_losses = 0.0002
hyperparameters_losses['regularization_rate'] = regularization_rate_losses
learning_rate_losses = 0.00014
hyperparameters_losses['learning_rate'] = learning_rate_losses
filters_losses = [40]
hyperparameters_losses['filters'] = filters_losses
lstm_dims_losses = [52]
hyperparameters_losses['lstm_dims'] = lstm_dims_losses

dropout_rnn_losses = 0.74
dropout_cnn_losses = 0.87

nrepochs_losses = 193

# %%
# from GC_find_best_arch_250_rnn_1_cnn_1_pulsi_rebalance / metrics (MAPE)
hyperparameters_losses = {}
regularization_rate_losses = 0.0002
hyperparameters_losses['regularization_rate'] = regularization_rate_losses
learning_rate_losses = 0.0001
hyperparameters_losses['learning_rate'] = learning_rate_losses
filters_losses = [33]
hyperparameters_losses['filters'] = filters_losses
lstm_dims_losses = [78]
hyperparameters_losses['lstm_dims'] = lstm_dims_losses

dropout_rnn_losses = 0.72
dropout_cnn_losses = 0.81

nrepochs_losses = 192

# %%
# from GC_find_best_arch_250_rnn_2_cnn_2_pulsi / metrics (MAPE)
hyperparameters_losses = {}
regularization_rate_losses = 0.01
hyperparameters_losses['regularization_rate'] = regularization_rate_losses
learning_rate_losses = 0.00075
hyperparameters_losses['learning_rate'] = learning_rate_losses
filters_losses = [58, 78]
hyperparameters_losses['filters'] = filters_losses
lstm_dims_losses = [34]
hyperparameters_losses['lstm_dims'] = lstm_dims_losses

dropout_rnn_losses = 0.34
dropout_cnn_losses = 0.66

nrepochs_losses = 108

# %%
# from GC_find_best_arch_250_rnn_3_cnn_3_pulsi / losses
hyperparameters_losses = {}
regularization_rate_losses = 0.0006
hyperparameters_losses['regularization_rate'] = regularization_rate_losses
learning_rate_losses = 0.024
hyperparameters_losses['learning_rate'] = learning_rate_losses
filters_losses = [46, 12]
hyperparameters_losses['filters'] = filters_losses
lstm_dims_losses = [33, 41, 14]
hyperparameters_losses['lstm_dims'] = lstm_dims_losses

dropout_rnn_losses = 0.40
dropout_cnn_losses = 0.255

nrepochs_losses = 50

# %%
# from GC_find_best_arch_250_rnn_4_cnn_4_pulsi / metric
hyperparameters_losses = {}
regularization_rate_losses = 0.031
hyperparameters_losses['regularization_rate'] = regularization_rate_losses
learning_rate_losses = 0.0007
hyperparameters_losses['learning_rate'] = learning_rate_losses
filters_losses = [63, 33, 40, 98]
hyperparameters_losses['filters'] = filters_losses
lstm_dims_losses = [77]
hyperparameters_losses['lstm_dims'] = lstm_dims_losses

dropout_rnn_losses = 0.61
dropout_cnn_losses = 0.43

nrepochs_losses = 89

# %%
model = generate_DeepConvLSTM_model(dim_length, dim_channels, output_dim,
                                    filters_losses, lstm_dims_losses, learning_rate_losses,
                                    regularization_rate_losses, dropout=None,
                                    dropout_rnn=dropout_rnn_losses, dropout_cnn=dropout_cnn_losses,
                                    metrics=[mean_absolute_percentage_error])
models_losses = [(model, hyperparameters_losses)]

# %%
# in this case, find_best_architecture is only used for training the model
np.random.seed(3)
verbose=True
early_stopping=False

best_model_losses, best_params_losses, best_model_metrics, best_params_metrics, debug = \
    find_best_architecture(train_gen_reduced, val_gen_reduced, test_gen_reduced,
                           verbose=False, number_of_models=None, nr_epochs=nrepochs_losses,
                           early_stopping=True, batch_size=batch_size,
                           models=models_losses, metric=mean_absolute_percentage_error, use_testset=True,
                           debug=False, test_retrain=False, output_all=True)

# %%
# results for GC_find_best_arch_250_rnn_1_pulsi_rebalance / losses
train_predict, val_predict, test_predict = \
    evaluate_model(train_gen_reduced, val_gen_reduced, test_gen_reduced,
                   best_model_losses)
# Out:
# training error = [0.026703921886972893, 16173118.98076923]
# validation error = [0.028075694106519222, 25.001705805460613]
# testing error = [0.0038682045257753795, 5.527839527977838]

# %%
# results for GC_find_best_arch_250_rnn_1_pulsi_rebalance / metrics
train_predict, val_predict, test_predict = \
    evaluate_model(train_gen_reduced, val_gen_reduced, test_gen_reduced,
                   best_model_losses)
# Out:
# training error = [0.02768795509846547, 16433831.108974358]
# validation error = [0.030320135410875082, 25.035001436869305]
# testing error = [0.003372180883048309, 3.5689883202446833]

# %%
# results for GC_find_best_arch_250_rnn_1_cnn_1_pulsi_rebalance / lossses
train_predict, val_predict, test_predict = \
    evaluate_model(train_gen_reduced, val_gen_reduced, test_gen_reduced,
                   best_model_losses)
# Out:
# training error = [0.02660321893218236, 15183669.948717948]
# validation error = [0.03076387657266524, 25.528309451209175]
# testing error = [0.0035477529743479356, 3.196770892461141]

# %%
# results for GC_find_best_arch_250_rnn_1_cnn_1_pulsi_rebalance / metrics
train_predict, val_predict, test_predict = \
    evaluate_model(train_gen_reduced, val_gen_reduced, test_gen_reduced,
                   best_model_losses)
# Out:
# training error = [0.022842249928567655, 11667547.278846154]
# validation error = [0.03039985103532672, 24.74775701098972]
# testing error = [0.004394486421512233, 3.7024138908386233]

# %%
# results for GC_find_best_arch_250_rnn_2_cnn_2_pulsi / metrics
train_predict, val_predict, test_predict = \
    evaluate_model(train_gen_reduced, val_gen_reduced, test_gen_reduced,
                   best_model_losses)
# Out:
# training error = [0.007144125470987115, 3629835.8958333335]
# validation error = [0.039504802889294095, 27.414820512135822]
# testing error = [0.006312266101439794, 2.457550123002794]

# %%
# results for GC_find_best_arch_250_rnn_3_cnn_3_pulsi / losses
train_predict, val_predict, test_predict = \
    evaluate_model(train_gen_reduced, val_gen_reduced, test_gen_reduced,
                   best_model_losses)
# Out:
# training error = [0.012790429202887492, 4667160.584935897]
# validation error = [0.042607171978387565, 26.83086723751492]
# testing error = [0.010476135007209248, 2.9867611334058974]

# %%
# results for GC_find_best_arch_250_rnn_4_cnn_4_pulsi / losses
train_predict, val_predict, test_predict = \
    evaluate_model(train_gen_reduced, val_gen_reduced, test_gen_reduced,
                   best_model_losses)
# Out:
# training error = [0.012399009870699583, 6048174.721153846]
# validation error = [0.04843275466312965, 28.9890333281623]
# testing error = [0.010534591793186134, 3.0693692504035104]

# %%
# full dataset
train_names = np.array(['p_17-01-19', 'p_17-01-20', 'p_17-01-21', 'p_17-01-22', 'p_17-01-23', 'p_17-01-24', 'p_17-01-25',
                        'p_17-01-26', 'p_17-01-27', 'p_17-01-28', 'p_17-01-29', 'p_17-01-30', 'p_17-01-31', 'p_17-02-01',
                        'p_17-02-02', 'p_17-02-03', 'p_17-02-04', 'p_17-02-05', 'p_17-02-06', 'p_17-02-07', 'p_17-02-08',
                        'p_17-02-09', 'p_17-02-10'])
val_names = np.array(['p_17-02-11', 'p_17-02-12', 'p_17-02-13', 'p_17-02-14', 'p_17-02-15', 'p_17-02-16', 'p_17-02-17', 'p_17-02-18'])
test_names = np.array(['p_17-02-19', 'p_17-02-20', 'p_17-02-21', 'p_17-02-22', 'p_17-02-23', 'p_17-02-24', 'p_17-02-25', 'p_17-04-27'])
train_gen = DataGenerator(dataset_reduced_std, train_names,
                          "spo2", batch_size=batch_size,
                          number_of_predictions=number_of_predictions,
                          window_size=window_size,
                          step_prediction_dates=1, shuffle=False,
                          rebalance_data=True, rebalance_threshold=0.5,
                          debug=False)
val_gen = DataGenerator(dataset_reduced_std, val_names,
                        "spo2", batch_size=batch_size,
                        number_of_predictions=number_of_predictions,
                        window_size=window_size,
                        step_prediction_dates=1, shuffle=False,
                        rebalance_data=True, rebalance_threshold=0.5,
                        debug=False)
test_gen = DataGenerator(dataset_reduced_std, test_names,
                         "spo2", batch_size=batch_size,
                         number_of_predictions=number_of_predictions,
                         window_size=window_size,
                         step_prediction_dates=1, shuffle=False,
                         rebalance_data=False,
                         debug=False)

# %%
print(len(train_gen)*batch_size)
print(len(train_gen.get_minority_datetimes()))
print(len(val_gen)*batch_size)
print(len(val_gen.get_minority_datetimes()))
# Out:
# 26432
# 234
# 9504
# 68

# %%
# in this case, find_best_architecture is only used for training the model
np.random.seed(3)
verbose=True
early_stopping=False

best_model_losses, best_params_losses, best_model_metrics, best_params_metrics, debug = \
    find_best_architecture(train_gen, val_gen, test_gen,
                           verbose=True, number_of_models=None, nr_epochs=500, # let early stopping decide
                           early_stopping=True, batch_size=batch_size,
                           models=models_losses, metric=mean_absolute_percentage_error, use_testset=True,
                           debug=False, test_retrain=False, output_all=True)
# Out:
# Training model 0
# {'regularization_rate': 0.0002, 'learning_rate': 0.0001, 'filters': [33], 'lstm_dims': [78]}
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_2 (Batch (None, 12, 2)             8
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 12, 2, 1)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 12, 2, 33)         132
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 2, 33)         132
# _________________________________________________________________
# activation_1 (Activation)    (None, 12, 2, 33)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 2, 33)         0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 12, 66)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 12, 78)            45240
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 12, 78)            0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 12, 4)             316
# _________________________________________________________________
# lambda_2 (Lambda)            (None, 4)                 0
# =================================================================
# Total params: 45,828
# Trainable params: 45,758
# Non-trainable params: 70
# _________________________________________________________________
# Epoch 1/500
# 826/826 [==============================] - 15s 18ms/step - loss: 0.0316 - mean_absolute_percentage_error: 1393431.8904 - val_loss: 0.0207 - val_mean_absolute_percentage_error: 16.9063
# Epoch 2/500
# 826/826 [==============================] - 15s 18ms/step - loss: 0.0303 - mean_absolute_percentage_error: 1382463.8377 - val_loss: 0.0204 - val_mean_absolute_percentage_error: 16.6996
# Epoch 3/500
# 826/826 [==============================] - 15s 18ms/step - loss: 0.0298 - mean_absolute_percentage_error: 1445423.0095 - val_loss: 0.0202 - val_mean_absolute_percentage_error: 16.6946
# Epoch 4/500
# 826/826 [==============================] - 15s 18ms/step - loss: 0.0292 - mean_absolute_percentage_error: 1331981.6929 - val_loss: 0.0200 - val_mean_absolute_percentage_error: 16.5324
# Epoch 5/500
# 826/826 [==============================] - 15s 18ms/step - loss: 0.0289 - mean_absolute_percentage_error: 1447832.4484 - val_loss: 0.0199 - val_mean_absolute_percentage_error: 16.5507
# Epoch 6/500
# 826/826 [==============================] - 15s 18ms/step - loss: 0.0285 - mean_absolute_percentage_error: 1355016.8246 - val_loss: 0.0199 - val_mean_absolute_percentage_error: 16.6275
# Epoch 7/500
# 826/826 [==============================] - 15s 19ms/step - loss: 0.0284 - mean_absolute_percentage_error: 1334974.8238 - val_loss: 0.0197 - val_mean_absolute_percentage_error: 16.5399
# Epoch 8/500
# 826/826 [==============================] - 15s 18ms/step - loss: 0.0280 - mean_absolute_percentage_error: 1337684.4028 - val_loss: 0.0197 - val_mean_absolute_percentage_error: 16.6076
# Epoch 9/500
# 826/826 [==============================] - 16s 19ms/step - loss: 0.0278 - mean_absolute_percentage_error: 1409929.3861 - val_loss: 0.0194 - val_mean_absolute_percentage_error: 16.4155
# Epoch 10/500
# 826/826 [==============================] - 17s 20ms/step - loss: 0.0277 - mean_absolute_percentage_error: 1216310.0826 - val_loss: 0.0195 - val_mean_absolute_percentage_error: 16.4840
# Epoch 11/500
# 826/826 [==============================] - 15s 19ms/step - loss: 0.0276 - mean_absolute_percentage_error: 1315282.7433 - val_loss: 0.0196 - val_mean_absolute_percentage_error: 16.6709
# Epoch 12/500
# 826/826 [==============================] - 15s 18ms/step - loss: 0.0272 - mean_absolute_percentage_error: 1253903.8503 - val_loss: 0.0194 - val_mean_absolute_percentage_error: 16.5234
# Epoch 13/500
# 826/826 [==============================] - 16s 19ms/step - loss: 0.0270 - mean_absolute_percentage_error: 1163337.8571 - val_loss: 0.0193 - val_mean_absolute_percentage_error: 16.4182
# Epoch 14/500
# 826/826 [==============================] - 15s 19ms/step - loss: 0.0271 - mean_absolute_percentage_error: 1249159.8258 - val_loss: 0.0192 - val_mean_absolute_percentage_error: 16.3983
# Epoch 15/500
# 826/826 [==============================] - 15s 18ms/step - loss: 0.0269 - mean_absolute_percentage_error: 1153200.7341 - val_loss: 0.0193 - val_mean_absolute_percentage_error: 16.4981
# Epoch 16/500
# 826/826 [==============================] - 15s 19ms/step - loss: 0.0269 - mean_absolute_percentage_error: 1062211.7507 - val_loss: 0.0192 - val_mean_absolute_percentage_error: 16.4096
# Epoch 17/500
# 826/826 [==============================] - 15s 18ms/step - loss: 0.0267 - mean_absolute_percentage_error: 953813.7514 - val_loss: 0.0191 - val_mean_absolute_percentage_error: 16.3316
# Epoch 18/500
# 826/826 [==============================] - 16s 19ms/step - loss: 0.0265 - mean_absolute_percentage_error: 994971.8600 - val_loss: 0.0192 - val_mean_absolute_percentage_error: 16.4719
# Epoch 19/500
# 826/826 [==============================] - 16s 19ms/step - loss: 0.0264 - mean_absolute_percentage_error: 967142.5563 - val_loss: 0.0193 - val_mean_absolute_percentage_error: 16.5170
# Epoch 20/500
# 826/826 [==============================] - 16s 19ms/step - loss: 0.0263 - mean_absolute_percentage_error: 899907.2871 - val_loss: 0.0190 - val_mean_absolute_percentage_error: 16.2412
# Epoch 21/500
# 826/826 [==============================] - 15s 19ms/step - loss: 0.0263 - mean_absolute_percentage_error: 1034733.3974 - val_loss: 0.0190 - val_mean_absolute_percentage_error: 16.3016
# Epoch 22/500
# 826/826 [==============================] - 15s 19ms/step - loss: 0.0263 - mean_absolute_percentage_error: 1074538.5602 - val_loss: 0.0192 - val_mean_absolute_percentage_error: 16.4172
# Epoch 23/500
# 826/826 [==============================] - 15s 19ms/step - loss: 0.0262 - mean_absolute_percentage_error: 942958.6350 - val_loss: 0.0192 - val_mean_absolute_percentage_error: 16.5320
# Epoch 24/500
# 826/826 [==============================] - 15s 19ms/step - loss: 0.0260 - mean_absolute_percentage_error: 1044071.5823 - val_loss: 0.0191 - val_mean_absolute_percentage_error: 16.4127
# Epoch 25/500
# 826/826 [==============================] - 16s 19ms/step - loss: 0.0260 - mean_absolute_percentage_error: 920911.9213 - val_loss: 0.0190 - val_mean_absolute_percentage_error: 16.3159
# Epoch 26/500
# 826/826 [==============================] - 16s 20ms/step - loss: 0.0258 - mean_absolute_percentage_error: 826226.8517 - val_loss: 0.0192 - val_mean_absolute_percentage_error: 16.4293
# Epoch 27/500
# 826/826 [==============================] - 16s 19ms/step - loss: 0.0259 - mean_absolute_percentage_error: 896487.5019 - val_loss: 0.0192 - val_mean_absolute_percentage_error: 16.4433
# Epoch 28/500
# 826/826 [==============================] - 17s 20ms/step - loss: 0.0257 - mean_absolute_percentage_error: 916471.3425 - val_loss: 0.0191 - val_mean_absolute_percentage_error: 16.3478
# Epoch 29/500
# 826/826 [==============================] - 16s 19ms/step - loss: 0.0258 - mean_absolute_percentage_error: 832182.9905 - val_loss: 0.0192 - val_mean_absolute_percentage_error: 16.4420
# Epoch 30/500
# 826/826 [==============================] - 15s 19ms/step - loss: 0.0258 - mean_absolute_percentage_error: 893168.3088 - val_loss: 0.0191 - val_mean_absolute_percentage_error: 16.3628
# Epoch 31/500
# 826/826 [==============================] - 16s 19ms/step - loss: 0.0256 - mean_absolute_percentage_error: 756804.7511 - val_loss: 0.0191 - val_mean_absolute_percentage_error: 16.3502
# Epoch 32/500
# 826/826 [==============================] - 15s 19ms/step - loss: 0.0255 - mean_absolute_percentage_error: 888152.6709 - val_loss: 0.0190 - val_mean_absolute_percentage_error: 16.3692
# Epoch 33/500
# 826/826 [==============================] - 16s 19ms/step - loss: 0.0256 - mean_absolute_percentage_error: 815543.0891 - val_loss: 0.0191 - val_mean_absolute_percentage_error: 16.4127
# Epoch 34/500
# 826/826 [==============================] - 16s 20ms/step - loss: 0.0254 - mean_absolute_percentage_error: 741122.7889 - val_loss: 0.0190 - val_mean_absolute_percentage_error: 16.3390
# Epoch 35/500
# 826/826 [==============================] - 17s 20ms/step - loss: 0.0253 - mean_absolute_percentage_error: 763420.1857 - val_loss: 0.0191 - val_mean_absolute_percentage_error: 16.3975
# Epoch 36/500
# 826/826 [==============================] - 16s 19ms/step - loss: 0.0253 - mean_absolute_percentage_error: 770394.5373 - val_loss: 0.0194 - val_mean_absolute_percentage_error: 16.5446
# Epoch 37/500
# 826/826 [==============================] - 17s 20ms/step - loss: 0.0254 - mean_absolute_percentage_error: 835413.7563 - val_loss: 0.0192 - val_mean_absolute_percentage_error: 16.4090
# Epoch 38/500
# 826/826 [==============================] - 17s 21ms/step - loss: 0.0252 - mean_absolute_percentage_error: 739518.8013 - val_loss: 0.0192 - val_mean_absolute_percentage_error: 16.4406
# Epoch 39/500
# 826/826 [==============================] - 16s 20ms/step - loss: 0.0252 - mean_absolute_percentage_error: 780350.6492 - val_loss: 0.0192 - val_mean_absolute_percentage_error: 16.4795
# Epoch 40/500
# 826/826 [==============================] - 16s 19ms/step - loss: 0.0251 - mean_absolute_percentage_error: 763639.5344 - val_loss: 0.0193 - val_mean_absolute_percentage_error: 16.5585
# Epoch 41/500
# 826/826 [==============================] - 16s 20ms/step - loss: 0.0249 - mean_absolute_percentage_error: 800239.1574 - val_loss: 0.0190 - val_mean_absolute_percentage_error: 16.2726
# Epoch 42/500
# 826/826 [==============================] - 16s 20ms/step - loss: 0.0249 - mean_absolute_percentage_error: 794123.3054 - val_loss: 0.0193 - val_mean_absolute_percentage_error: 16.5442
# Epoch 43/500
# 826/826 [==============================] - 16s 20ms/step - loss: 0.0248 - mean_absolute_percentage_error: 747795.2889 - val_loss: 0.0194 - val_mean_absolute_percentage_error: 16.6331
# Epoch 44/500
# 826/826 [==============================] - 16s 19ms/step - loss: 0.0248 - mean_absolute_percentage_error: 792877.5900 - val_loss: 0.0194 - val_mean_absolute_percentage_error: 16.5572
# Epoch 45/500
# 826/826 [==============================] - 16s 19ms/step - loss: 0.0247 - mean_absolute_percentage_error: 755604.1629 - val_loss: 0.0194 - val_mean_absolute_percentage_error: 16.6018
# Epoch 00045: early stopping
# [16.601765016112665]
# [0.019399715509102602]
# => Best model for losses
# Best model: model  0
# Hyperparameters:  {'regularization_rate': 0.0002, 'learning_rate': 0.0001, 'filters': [33], 'lstm_dims': [78]}
# Loss on validation set:  0.019399715509102602
# mean_absolute_percentage_error on validation set:  16.601765016112665
# => Best model for losses is the same as the best model for metric...

# %%
# results for GC_find_best_arch_250_rnn_1_pulsi_rebalance / losses
train_predict, val_predict, test_predict = \
    evaluate_model(train_gen, val_gen, test_gen,
                   best_model_losses)
# Out:
# training error = [0.02146031775852309, 1284006.314201408]
# validation error = [0.019858876531724176, 17.285627509608414]
# testing error = [0.0052610699045434394, 6.497343507925243]

# %%
# results for GC_find_best_arch_250_rnn_1_pulsi_rebalance / metrics
train_predict, val_predict, test_predict = \
    evaluate_model(train_gen, val_gen, test_gen,
                   best_model_losses)
# Out:
# training error = [0.02050680126070291, 1240517.3724826588]
# validation error = [0.02131436028916025, 17.130954225456673]
# testing error = [0.0045836071455451705, 4.89058465535775]

# %%
# results for GC_find_best_arch_250_rnn_1_cnn_1_pulsi_rebalance / losses
train_predict, val_predict, test_predict = \
    evaluate_model(train_gen, val_gen, test_gen,
                   best_model_losses)
# Out:
# training error = [0.02381990463236126, 875825.3857024114]
# validation error = [0.019089871042279483, 16.642975457188257]
# testing error = [0.004334271024593, 5.093053975501585]

# %%
# results for GC_find_best_arch_250_rnn_1_cnn_1_pulsi / metrics
train_predict, val_predict, test_predict = \
    evaluate_model(train_gen, val_gen, test_gen,
                   best_model_losses)
# Out:
# training error = [0.003938880632913358, 569377.7372120708]
# validation error = [0.02409494689568526, 17.976693040995485]
# testing error = [0.004958599644935323, 4.8252417439110475]

# %%
# results for GC_find_best_arch_250_rnn_2_cnn_2_pulsi / metrics
train_predict, val_predict, test_predict = \
    evaluate_model(train_gen, val_gen, test_gen,
                   best_model_losses)
# Out:
# training error = [0.013877629461420867, 804774.5821229165]
# validation error = [0.027929954161798512, 17.259500298034464]
# testing error = [0.009675111871402482, 4.12370548864472]

# %%
# results for GC_find_best_arch_250_rnn_3_cnn_3_pulsi / losses
train_predict, val_predict, test_predict = \
    evaluate_model(train_gen, val_gen, test_gen,
                   best_model_losses)
# Out:
# training error = [0.029506070151492123, 1556520.3740879248]
# validation error = [0.020199085990286837, 16.7002499801944]
# testing error = [0.005257628673522786, 5.103903836615923]

# %%
# results for GC_find_best_arch_250_rnn_4_cnn_4_pulsi / losses
train_predict, val_predict, test_predict = \
    evaluate_model(train_gen, val_gen, test_gen,
                   best_model_losses)
# Out:
# training error = [0.02016231472903894, 1163866.7292111735]
# validation error = [0.022170260178571197, 16.918399062622274]
# testing error = [0.00649275392740865, 4.635836825946061]

# %%
from utils.validate_models import mape
evaluate_plot(dataset_reduced, test_gen, test_predict,
              target_variable=target_variable, metric=mape,
              prediction=0)
# Out:
# (1.403065152237634, 1.3869434564813004)

# %%
for prediction in range(371,385):
    print(prediction)
    evaluate_plot(dataset_reduced, test_gen, test_predict,
                  target_variable=target_variable, metric=mape,
                  prediction=prediction)
# Out:
# 371
# 372
# 373
# 374
# 375
# 376
# 377
# 378
# 379
# 380
# 381
# 382
# 383
# 384

# %%
hyperparameters_losses
# Out:
# {'regularization_rate': 0.0002,
#  'learning_rate': 0.00014,
#  'filters': [40],
#  'lstm_dims': [52]}
